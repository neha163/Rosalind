# %%
seq1 = '...'
seq2 = '...'
count = 0
#mutation at any single nt. while comparing 2 sequences 
for i in range(0, len(seq1)):
    if seq1[i] != seq2[i]:
        count += 1;
        
count
# Out:
# 471
