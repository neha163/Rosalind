# %%
dna = '...'
#to store complementary seq
comp=''
for i in dna:
    if i == 'A':
        comp = comp + 'T'
    elif i == 'T':
        comp = comp + 'A'
    elif i == 'G':
        comp = comp + 'C'
    elif i == 'C':
        comp = comp + 'G'
        
#to do reverse 
print(comp[::-1])
# Out:
# ...
